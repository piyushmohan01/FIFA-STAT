# %%
import numpy as np
import pandas as pd
from mplsoccer import VerticalPitch

# %%
pitch = VerticalPitch(
    positional=True,
    positional_linewidth=0.1,
    pitch_color='#1a1a1a',
    line_color='white',
    linewidth=1,
    spot_scale=0.006,
)
fig, ax = pitch.draw()
